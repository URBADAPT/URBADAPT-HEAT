# %% [markdown]
# # Notebook 09 - Uncertainty Quantification (Second version)
#
# City-agnostic improved workflow for **Athens**. This version keeps the original March 2026 `NB09` untouched and adds three targeted improvements:
# - spatially explicit daily raster modifiers for trees and waste heat
# - event-level warning-day logic for EWS
# - EWS CBA uncertainty outputs alongside the impact uncertainty outputs
#
# All new outputs are written to `outputs/athens/tables/uncertainty_improved_fast/` so the original `NB09` outputs remain unchanged.

# %%
import os
import sys
from pathlib import Path

os.environ.setdefault('CITY', 'athens')
os.environ.setdefault('NB09_N', '512')
os.environ.setdefault('NB09_SEED', '42')
os.environ.setdefault('NB09_MAKE_FIGURES', '0')
os.environ.setdefault('HAZARD_TRACK', 'standard')

def _find_repo_root():
    env = os.environ.get("URBAN_HEAT_ROOT")
    if env:
        root = Path(env).expanduser().resolve()
        if (root / "cityheat").is_dir() and (root / "configs").is_dir():
            return root
    start = Path.cwd().resolve()
    for cand in [start, *start.parents]:
        if (cand / "cityheat").is_dir() and (cand / "configs").is_dir():
            return cand
    raise RuntimeError(
        "Could not locate repo root. Run the notebook from inside the repo "
        "or set URBAN_HEAT_ROOT."
    )

ROOT = _find_repo_root()
os.environ.setdefault('MPLCONFIGDIR', str(ROOT / 'outputs' / '.mpl'))
os.environ.setdefault('XDG_CACHE_HOME', str(ROOT / 'outputs' / '.cache'))
Path(os.environ['MPLCONFIGDIR']).mkdir(parents=True, exist_ok=True)
Path(os.environ['XDG_CACHE_HOME']).mkdir(parents=True, exist_ok=True)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print('ROOT:', ROOT)
print('CITY:', os.environ['CITY'])
print('NB09_N:', os.environ['NB09_N'])
print('NB09_SEED:', os.environ['NB09_SEED'])
# Out:
# ROOT: /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat
# CITY: athens
# NB09_N: 512
# NB09_SEED: 42

# %%
from cityheat.nb09_improved_fast import run_nb09_improved_fast

paths = run_nb09_improved_fast()
paths
# Out:
# 2026-04-08 14:15:42,400 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:42,915 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:43,416 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:44,378 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:44,890 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:45,408 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:46,373 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:47,067 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:47,743 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:49,544 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:51,041 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:52,154 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:53,807 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:54,453 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:55,071 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:56,279 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:56,873 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:57,417 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:58,829 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:59,400 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:00,248 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:02,711 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:03,893 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:04,695 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# [athens] sample 1/512: year=2050 aai=2.826
# 2026-04-08 14:16:53,666 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:54,266 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:54,861 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:55,965 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:56,517 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:57,079 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:58,199 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:58,791 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:59,416 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:00,613 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:01,221 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:01,826 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:03,033 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:03,510 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:03,969 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:05,022 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:05,475 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:05,952 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:06,997 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:07,498 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:08,011 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:09,151 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:09,658 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:10,141 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# [athens] sample 2/512: year=2040 aai=2.073
# 2026-04-08 14:17:58,051 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:58,709 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:59,289 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:00,465 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:01,042 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:01,624 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:02,749 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:03,356 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:03,948 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:05,129 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:05,705 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:06,303 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:07,528 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:08,136 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:08,728 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:09,957 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:10,551 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:11,148 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18:12,332 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:18
- climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:44,683 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:45,705 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:46,234 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:46,769 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:47,792 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:48,220 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:48,654 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:49,603 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:50,032 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:50,474 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:51,450 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:51,914 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:52,349 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:53,280 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:53,726 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 16:13:54,155 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# [athens] sample 512/512: year=2020 aai=0.170
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/analyze/pawn.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   cv = np.nanstd(p_ind) / mean
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/analyze/pawn.py:138: RuntimeWarning: All-NaN slice encountered
#   mins = np.nanmin(p_ind)
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/analyze/pawn.py:139: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(p_ind)
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/analyze/pawn.py:140: RuntimeWarning: All-NaN slice encountered
#   med = np.nanmedian(p_ind)
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/analyze/pawn.py:141: RuntimeWarning: All-NaN slice encountered
#   maxs = np.nanmax(p_ind)
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# {'samples': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/unc_samples_athens_improved.csv'),
#  'impact': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/unc_impact_summary_athens_improved.csv'),
#  'freq': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/unc_freq_curve_athens_improved.csv'),
#  'cba': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/unc_cba_ews_athens_improved.csv'),
#  'cba_ac': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/unc_cba_ac_athens_improved.csv'),
#  'cba_trees': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/unc_cba_trees_athens_improved.csv'),
#  'vuln': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/unc_vulnerability_athens_improved.csv'),
#  'sens_aai': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/sens_aai_agg_athens_improved.csv'),
#  'sens_freq': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/sens_freq_curve_athens_improved.csv'),
#  'sens_cba': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/sens_cba_ews_athens_improved.csv'),
#  'sens_cba_ac': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/sens_cba_ac_athens_improved.csv'),
#  'sens_cba_trees': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/sens_cba_trees_athens_improved.csv'),
#  'sens_vuln': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/sens_vulnerability_athens_improved.csv'),
#  'meta': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/uq_dimensions_athens_improved.json'),
#  'bundle': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/unc_impact_athens_march2026_improved.h5'),
#  'bundle_sens': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/athens/tables/uncertainty_improved/unc_impact_athens_march2026_improved_with_sensitivity.h5')}

# %%
import pandas as pd

samples = pd.read_csv(paths['samples'])
samples[[
    'year', 'aai_agg', 'annual_deaths', 'sample_warning_days',
    'sample_threshold_deaths_per_day', 'ews_pv_cost_25y',
    'ews_net_avoided_deaths_25y_cum', 'ews_cost_per_net_death_25y_cum'
]].head(10)
# Out:
#    year   aai_agg  annual_deaths  sample_warning_days  \
# 0  2050  2.825606    1031.346109                 41.0
# 1  2040  2.072584     758.565625                 41.0
# 2  2040  0.194704      71.261719                 33.0
# 3  2020  2.259164     826.854028                 30.0
# 4  2050  5.570874    2033.369033                 47.0
# 5  2040  0.662847     242.601827                 34.0
# 6  2050  1.792041     654.094811                 47.0
# 7  2040  2.084205     762.819099                 43.0
# 8  2050  0.654039     238.724147                 69.0
# 9  2020  0.378475     138.521876                 30.0
#
#    sample_threshold_deaths_per_day  ews_pv_cost_25y  \
# 0                         9.197733     2.342248e+06
# 1                         7.677598     2.201145e+07
# 2                         0.991797     2.216243e+06
# 3                         9.387727     3.682441e+06
# 4                        17.563434     2.174854e+06
# 5                         3.320090     3.408287e+06
# 6                         4.997026     1.949458e+07
# 7                         6.903599     2.287663e+07
# 8                         1.612799     3.088083e+06
# 9                         1.973208     4.184520e+06
#
#    ews_net_avoided_deaths_25y_cum  ews_cost_per_net_death_25y_cum
# 0                      540.232255                     4335.631231
# 1                     1015.060310                    21684.866208
# 2                       90.741871                    24423.602428
# 3                     2776.440596                     1326.317378
# 4                      616.495172                     3527.771539
# 5                      691.794218                     4926.734882
# 6                      501.808874                    38848.609393
# 7                     2405.772404                     9509.059765
# 8                      110.939040                    27835.852823
# 9                       80.549590                    51949.613894

# %%
impact_summary = pd.read_csv(paths['impact'])
cba_summary = pd.read_csv(paths['cba'])

display(impact_summary.describe())
display(cba_summary.describe())
# Out:
#           aai_agg  annual_deaths         rp2         rp5        rp10  \
# count  512.000000     512.000000  512.000000  512.000000  512.000000
# mean     1.539062     562.493487    0.093830    3.153413    5.382491
# std      1.605850     586.953988    0.262495    3.836874    5.317242
# min      0.052082      19.009749    0.000000    0.010848    0.219100
# 25%      0.390114     142.781784    0.000000    0.497032    1.451974
# 50%      0.964664     352.859413    0.000000    1.685948    3.641219
# 75%      2.124035     775.807869    0.013496    4.187954    7.599127
# max      9.048240    3311.655679    1.981239   21.541540   28.500984
#
#              rp20
# count  512.000000
# mean     7.043164
# std      6.369608
# min      0.317951
# 25%      2.223682
# 50%      5.004265
# 75%     10.223126
# max     34.215176
#        ews_pv_cost_25y  ews_net_avoided_deaths_25y_cum  \
# count     5.120000e+02                      512.000000
# mean      1.279234e+07                      604.916210
# std       1.034349e+07                      711.032377
# min       1.720182e+06                        9.770684
# 25%       3.204862e+06                      135.854459
# 50%       8.183274e+06                      333.783853
# 75%       2.170804e+07                      796.005247
# max       3.940591e+07                     4710.685533
#
#        ews_net_avoided_deaths_25y_pv  ews_cost_per_net_death_25y_cum  \
# count                     512.000000                    5.120000e+02
# mean                      385.724814                    9.175428e+04
# std                       471.452344                    2.062580e+05
# min                         6.604114                    8.294496e+02
# 25%                        81.298391                    7.645927e+03
# 50%                       217.217920                    2.356937e+04
# 75%                       502.265611                    8.435191e+04
# max                      3392.186386                    2.519677e+06
#
#        ews_cost_per_net_death_25y_pv  ews_life_years_saved_25y_cum
# count                   5.120000e+02                    512.000000
# mean                    1.411045e+05                   7726.061844
# std                     3.073327e+05                   9277.421716
# min                     1.262045e+03                    122.383597
# 25%                     1.154397e+04                   1733.436560
# 50%                     3.832758e+04                   4172.243764
# 75%                     1.311643e+05                  10171.534453
# max                     3.893442e+06                  62319.369954
