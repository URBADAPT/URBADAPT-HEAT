# %% [markdown]
# # Notebook 09 - Uncertainty Quantification (Second version)
#
# City-agnostic improved workflow for **Lisbon**. This version keeps the original March 2026 `NB09` untouched and adds three targeted improvements:
# - spatially explicit daily raster modifiers for trees and waste heat
# - event-level warning-day logic for EWS
# - EWS CBA uncertainty outputs alongside the impact uncertainty outputs
#
# All new outputs are written to `outputs/lisbon/tables/uncertainty_improved_fast/` so the original `NB09` outputs remain unchanged.

# %%
import os
import sys
from pathlib import Path

os.environ.setdefault('CITY', 'lisbon')
os.environ.setdefault('NB09_N', '512')
os.environ.setdefault('NB09_SEED', '42')
os.environ.setdefault('NB09_MAKE_FIGURES', '0')
os.environ.setdefault('HAZARD_TRACK', 'standard')

def _find_repo_root():
    env = os.environ.get("URBAN_HEAT_ROOT")
    if env:
        root = Path(env).expanduser().resolve()
        if (root / "cityheat").is_dir() and (root / "configs").is_dir():
            return root
    start = Path.cwd().resolve()
    for cand in [start, *start.parents]:
        if (cand / "cityheat").is_dir() and (cand / "configs").is_dir():
            return cand
    raise RuntimeError(
        "Could not locate repo root. Run the notebook from inside the repo "
        "or set URBAN_HEAT_ROOT."
    )

ROOT = _find_repo_root()
os.environ.setdefault('MPLCONFIGDIR', str(ROOT / 'outputs' / '.mpl'))
os.environ.setdefault('XDG_CACHE_HOME', str(ROOT / 'outputs' / '.cache'))
Path(os.environ['MPLCONFIGDIR']).mkdir(parents=True, exist_ok=True)
Path(os.environ['XDG_CACHE_HOME']).mkdir(parents=True, exist_ok=True)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print('ROOT:', ROOT)
print('CITY:', os.environ['CITY'])
print('NB09_N:', os.environ['NB09_N'])
print('NB09_SEED:', os.environ['NB09_SEED'])
# Out:
# ROOT: /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat
# CITY: lisbon
# NB09_N: 512
# NB09_SEED: 42

# %%
from cityheat.nb09_improved_fast import run_nb09_improved_fast

paths = run_nb09_improved_fast()
paths
# Out:
# 2026-04-08 14:15:37,598 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:37,988 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:38,376 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:39,196 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:39,568 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:39,954 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:40,749 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:41,143 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:41,535 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:42,334 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:42,716 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:43,114 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:43,948 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:44,342 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:44,734 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:45,528 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:45,926 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:46,324 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:47,460 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:47,941 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:48,471 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:50,389 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:51,446 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:15:52,421 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# [lisbon] sample 1/512: year=2050 aai=0.389
# 2026-04-08 14:16:34,705 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:35,129 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:35,560 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:36,449 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:36,864 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:37,292 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:38,200 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:38,618 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:39,073 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:39,978 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:40,389 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:40,817 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:41,721 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:42,070 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:42,447 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:43,326 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:43,692 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:44,036 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:44,885 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:45,249 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:45,595 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:46,430 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:46,785 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:16:47,121 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# [lisbon] sample 2/512: year=2040 aai=0.181
# 2026-04-08 14:17:24,449 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:24,898 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:25,345 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:26,269 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:26,725 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:27,181 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:28,102 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:28,546 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:29,003 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17:29,919 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-08 14:17
- climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:35:13,830 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:35:15,438 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:35:16,090 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:35:16,696 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# [lisbon] sample 511/512: year=2030 aai=0.345
# 2026-04-09 13:36:17,206 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:17,906 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:18,630 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:20,454 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:21,114 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:21,806 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:23,473 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:24,225 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:24,897 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:26,438 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:27,172 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:27,896 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:29,755 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:30,581 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:31,402 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:33,529 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:34,497 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:35,446 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:37,830 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:39,118 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:40,274 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:42,522 - climada.hazard.base - WARNING - Impact function id=1 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:43,503 - climada.hazard.base - WARNING - Impact function id=2 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# 2026-04-09 13:36:44,411 - climada.hazard.base - WARNING - Impact function id=3 has mdr(0) != 0.The mean damage ratio must thus be computed for all values ofhazard intensity including 0 which can be very time consuming.
# [lisbon] sample 512/512: year=2020 aai=0.004
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/analyze/pawn.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   cv = np.nanstd(p_ind) / mean
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/analyze/pawn.py:138: RuntimeWarning: All-NaN slice encountered
#   mins = np.nanmin(p_ind)
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/analyze/pawn.py:139: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(p_ind)
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/analyze/pawn.py:140: RuntimeWarning: All-NaN slice encountered
#   med = np.nanmedian(p_ind)
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/analyze/pawn.py:141: RuntimeWarning: All-NaN slice encountered
#   maxs = np.nanmax(p_ind)
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# /opt/anaconda3/envs/urbanheat/lib/python3.10/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# {'samples': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/unc_samples_lisbon_improved.csv'),
#  'impact': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/unc_impact_summary_lisbon_improved.csv'),
#  'freq': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/unc_freq_curve_lisbon_improved.csv'),
#  'cba': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/unc_cba_ews_lisbon_improved.csv'),
#  'cba_ac': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/unc_cba_ac_lisbon_improved.csv'),
#  'cba_trees': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/unc_cba_trees_lisbon_improved.csv'),
#  'vuln': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/unc_vulnerability_lisbon_improved.csv'),
#  'sens_aai': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/sens_aai_agg_lisbon_improved.csv'),
#  'sens_freq': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/sens_freq_curve_lisbon_improved.csv'),
#  'sens_cba': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/sens_cba_ews_lisbon_improved.csv'),
#  'sens_cba_ac': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/sens_cba_ac_lisbon_improved.csv'),
#  'sens_cba_trees': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/sens_cba_trees_lisbon_improved.csv'),
#  'sens_vuln': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/sens_vulnerability_lisbon_improved.csv'),
#  'meta': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/uq_dimensions_lisbon_improved.json'),
#  'bundle': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/unc_impact_lisbon_march2026_improved.h5'),
#  'bundle_sens': PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/lisbon/tables/uncertainty_improved/unc_impact_lisbon_march2026_improved_with_sensitivity.h5')}

# %%
import pandas as pd

samples = pd.read_csv(paths['samples'])
samples[[
    'year', 'aai_agg', 'annual_deaths', 'sample_warning_days',
    'sample_threshold_deaths_per_day', 'ews_pv_cost_25y',
    'ews_net_avoided_deaths_25y_cum', 'ews_cost_per_net_death_25y_cum'
]].head(10)
# Out:
#    year   aai_agg  annual_deaths  sample_warning_days  \
# 0  2050  0.389079     142.013675                 25.0
# 1  2040  0.181135      66.295280                 30.0
# 2  2040  0.004766       1.744270                 17.0
# 3  2020  0.119385      43.694791                 23.0
# 4  2050  0.799399     291.780616                 25.0
# 5  2040  0.012968       4.746273                 26.0
# 6  2050  0.230295      84.057603                 26.0
# 7  2040  0.299019     109.440957                 29.0
# 8  2050  0.022314       8.144588                 38.0
# 9  2020  0.017304       6.333320                 23.0
#
#    sample_threshold_deaths_per_day  ews_pv_cost_25y  \
# 0                         1.793616     1.499511e+06
# 1                         0.729059     9.622491e+06
# 2                         0.005500     1.358382e+06
# 3                         0.539623     3.450479e+06
# 4                         2.999405     2.340024e+06
# 5                         0.067166     2.531833e+06
# 6                         0.933159     7.593689e+06
# 7                         1.316013     9.416571e+06
# 8                         0.030638     2.437769e+06
# 9                         0.023719     2.818584e+06
#
#    ews_net_avoided_deaths_25y_cum  ews_cost_per_net_death_25y_cum
# 0                       93.296546                    16072.527461
# 1                      122.858745                    78321.580795
# 2                        3.703370                   366796.089786
# 3                      185.035236                    18647.684391
# 4                      154.193055                    15175.936688
# 5                       17.079078                   148241.786414
# 6                       65.968228                   115111.314127
# 7                      385.355036                    24436.091624
# 8                        7.967480                   305964.920633
# 9                        6.531907                   431510.050735

# %%
impact_summary = pd.read_csv(paths['impact'])
cba_summary = pd.read_csv(paths['cba'])

display(impact_summary.describe())
display(cba_summary.describe())
# Out:
#           aai_agg  annual_deaths         rp2         rp5        rp10  \
# count  512.000000     512.000000  512.000000  512.000000  512.000000
# mean     0.138770      50.714944    0.007363    0.176991    0.410516
# std      0.205132      74.976050    0.032064    0.342127    0.656999
# min      0.000000       0.000000    0.000000    0.000000    0.000000
# 25%      0.009258       3.388500    0.000000    0.000000    0.000316
# 50%      0.047372      17.314557    0.000000    0.006037    0.088269
# 75%      0.170555      62.380182    0.000000    0.217694    0.519793
# max      1.160292     424.667030    0.305745    1.999909    3.634387
#
#              rp20
# count  512.000000
# mean     0.718748
# std      0.974292
# min      0.000000
# 25%      0.024658
# 50%      0.280305
# 75%      0.998097
# max      4.864515
#        ews_pv_cost_25y  ews_net_avoided_deaths_25y_cum  \
# count     5.120000e+02                      512.000000
# mean      8.767319e+06                       61.567122
# std       1.264582e+07                       89.991038
# min       1.102947e+06                        0.000000
# 25%       2.186877e+06                        5.299886
# 50%       5.582995e+06                       24.304335
# 75%       9.272269e+06                       77.192559
# max       6.632730e+07                      613.182887
#
#        ews_net_avoided_deaths_25y_pv  ews_cost_per_net_death_25y_cum  \
# count                     512.000000                    5.120000e+02
# mean                       39.600026                             inf
# std                        59.308201                             NaN
# min                         0.000000                    4.274057e+03
# 25%                         3.202544                    4.651736e+04
# 50%                        15.739988                    1.740687e+05
# 75%                        48.891511                    1.049075e+06
# max                       461.917109                             inf
#
#        ews_cost_per_net_death_25y_pv  ews_life_years_saved_25y_cum
# count                   5.120000e+02                    512.000000
# mean                             inf                    804.314779
# std                              NaN                   1187.910116
# min                     7.521782e+03                      0.000000
# 25%                     7.111819e+04                     67.507819
# 50%                     2.701131e+05                    301.637836
# 75%                     1.701310e+06                   1003.454892
# max                              inf                   8177.166956
