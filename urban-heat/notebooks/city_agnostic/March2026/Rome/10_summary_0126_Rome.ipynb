# %% [markdown]
# # Notebook 10 - Framework Summary (Rome)
#
# Thin wrapper around `cityheat.nb10_summary.run_nb10_summary`.
# It reads saved outputs from NB01-NB09 and writes summary figures to `outputs/rome/figures/summary/`.

# %%
from pathlib import Path
import sys

def _find_root() -> Path:
    start = Path.cwd()
    for cand in [start, *start.parents]:
        if (cand / "cityheat").is_dir() and (cand / "configs").is_dir():
            return cand
    raise RuntimeError("Repo root not found.")

ROOT = _find_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

CITY_SLUG = "rome"
ROOT
# Out:
# PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat')

# %%
from cityheat.nb10_summary import run_nb10_summary

results = run_nb10_summary(CITY_SLUG, verbose=True)
results
# Out:
# NB10 Summary Dashboard — Rome (rome)
# Using outputs in /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome
# [1_city_profile] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_01_city_profile_rome.png
# [2_climate_hazard] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_02_climate_hazard_rome.png
# [3_vulnerability] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_03_vulnerability_rome.png
# [4_mortality_if] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_04_mortality_if_rome.png
# [5_policy_levers] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_05_policy_levers_rome.png
# [6_cba_dashboard] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_06_cba_dashboard_rome.png
# [7_uncertainty] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_07_uncertainty_rome.png
# [summary_metrics] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/tables/rome_framework_summary_metrics.csv
# Done. 8 outputs saved.
# {'1_city_profile': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_01_city_profile_rome.png')],
#  '2_climate_hazard': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_02_climate_hazard_rome.png')],
#  '3_vulnerability': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_03_vulnerability_rome.png')],
#  '4_mortality_if': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_04_mortality_if_rome.png')],
#  '5_policy_levers': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_05_policy_levers_rome.png')],
#  '6_cba_dashboard': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_06_cba_dashboard_rome.png')],
#  '7_uncertainty': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_07_uncertainty_rome.png')],
#  'summary_metrics': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/tables/rome_framework_summary_metrics.csv')]}

# %%
from IPython.display import Image, display

figure_paths = [
    path
    for key, paths in results.items()
    if key != "summary_metrics"
    for path in paths
]

for path in figure_paths:
    print(path)
    display(Image(filename=str(path)))
# Out:
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_01_city_profile_rome.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_02_climate_hazard_rome.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_03_vulnerability_rome.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_04_mortality_if_rome.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_05_policy_levers_rome.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_06_cba_dashboard_rome.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/rome/figures/summary/summary_07_uncertainty_rome.png

# %%
import pandas as pd

metrics_path = ROOT / "outputs" / CITY_SLUG / "tables" / f"{CITY_SLUG}_framework_summary_metrics.csv"
metrics = pd.read_csv(metrics_path)
metrics
# Out:
#           section                            metric          value       unit
# 0    city_profile                   population_2020        2634831     people
# 1          hazard                citymean_degC_2020          14.29       degC
# 2          hazard                citymean_degC_2050           14.9       degC
# 3          hazard     delta_citymean_degC_2050_2020           0.61       degC
# 4   vulnerability                     svi_mean_2020            0.5        NaN
# 5   vulnerability                     svi_mean_2050          0.443        NaN
# 6       mortality              baseline_deaths_2020          534.3  deaths/yr
# 7       mortality              baseline_deaths_2050         1048.6  deaths/yr
# 8          policy  avoided_deaths_25y_trees_uniform           70.1     deaths
# 9          policy       avoided_deaths_25y_ac_gross          469.0     deaths
# 10         policy         avoided_deaths_25y_ac_net          152.9     deaths
# 11         policy   avoided_deaths_25y_ews_marginal          530.9     deaths
# 12            cba    best_cost_effectiveness_policy  EWS (central)        NaN
# 13            cba               best_cost_per_death        42955.0        EUR
# 14    uncertainty                    aai_agg_median           0.33        NaN
# 15    uncertainty                        aai_agg_p5          0.009        NaN
# 16    uncertainty                       aai_agg_p95          1.923        NaN
