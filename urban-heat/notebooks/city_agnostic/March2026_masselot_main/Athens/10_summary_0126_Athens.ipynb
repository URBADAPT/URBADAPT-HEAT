# %% [markdown]
# # Notebook 10 - Framework Summary (Athens)
#
# Thin wrapper around `cityheat.nb10_summary.run_nb10_summary`.
# It reads saved outputs from NB01-NB09 and writes summary figures to `outputs_variants/masselot_main/athens/figures/summary/`.

# %%
import os
os.environ["URBAN_HEAT_OUTPUT_VARIANT"] = "masselot_main"
os.environ["IF_MAIN_FAMILY"] = "masselot_tail"

# %%
from pathlib import Path
import sys

def _find_root() -> Path:
    start = Path.cwd()
    for cand in [start, *start.parents]:
        if (cand / "cityheat").is_dir() and (cand / "configs").is_dir():
            return cand
    raise RuntimeError("Repo root not found.")

ROOT = _find_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

CITY_SLUG = "athens"
ROOT
# Out:
# PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat')

# %%
from cityheat.nb10_summary_masselot_main import run_nb10_summary

results = run_nb10_summary(CITY_SLUG, verbose=True)
results
# Out:
# NB10 Masselot-main wrapper
#   Output variant: masselot_main
#   IF main family: masselot_tail
# NB10 Summary Dashboard — Athens (athens)
# Using outputs in /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens
# [1_city_profile] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_01_city_profile_athens.png
# [2_climate_hazard] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_02_climate_hazard_athens.png
# [3_vulnerability] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_03_vulnerability_athens.png
# [4_mortality_if] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_04_mortality_if_athens.png
# [5_policy_levers] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_05_policy_levers_athens.png
# [6_cba_dashboard] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_06_cba_dashboard_athens.png
# [7_uncertainty] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_07_uncertainty_athens.png
# [8_if_family_sensitivity] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_08_if_family_sensitivity_athens.png
# [summary_metrics] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/tables/athens_framework_summary_metrics.csv
# Done. 9 outputs saved.
# [9_if_source_comparison] saved -> /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_09_if_source_comparison_athens.png
# {'1_city_profile': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_01_city_profile_athens.png')],
#  '2_climate_hazard': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_02_climate_hazard_athens.png')],
#  '3_vulnerability': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_03_vulnerability_athens.png')],
#  '4_mortality_if': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_04_mortality_if_athens.png')],
#  '5_policy_levers': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_05_policy_levers_athens.png')],
#  '6_cba_dashboard': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_06_cba_dashboard_athens.png')],
#  '7_uncertainty': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_07_uncertainty_athens.png')],
#  '8_if_family_sensitivity': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_08_if_family_sensitivity_athens.png')],
#  'summary_metrics': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/tables/athens_framework_summary_metrics.csv')],
#  '9_if_source_comparison': [PosixPath('/Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_09_if_source_comparison_athens.png')]}

# %%
from IPython.display import Image, display

figure_paths = [
    path
    for key, paths in results.items()
    if key != "summary_metrics"
    for path in paths
]

for path in figure_paths:
    print(path)
    display(Image(filename=str(path)))
# Out:
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_01_city_profile_athens.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_02_climate_hazard_athens.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_03_vulnerability_athens.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_04_mortality_if_athens.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_05_policy_levers_athens.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_06_cba_dashboard_athens.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_07_uncertainty_athens.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_08_if_family_sensitivity_athens.png
# /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT-HEAT/urban-heat/outputs_variants/masselot_main/athens/figures/summary/summary_09_if_source_comparison_athens.png

# %%
from cityheat.nbsetup_masselot_main import resolve_city_output
CITY_OUT = resolve_city_output(ROOT, CITY_SLUG)

import pandas as pd

metrics_path = CITY_OUT / "tables" / f"{CITY_SLUG}_framework_summary_metrics.csv"
metrics = pd.read_csv(metrics_path)
metrics
# Out:
#                   section                                           metric  \
# 0              run_config                                   output_variant
# 1              run_config                                   if_main_family
# 2              run_config                                   if_main_source
# 3              run_config                           masselot_extrapolation
# 4              run_config                                       burke_role
# 5              run_config              current_original_workflow_preserved
# 6              run_config                      masselot_tail_extrapolation
# 7              run_config                     burke_recompute_audit_status
# 8              run_config                 burke_recompute_audit_fail_count
# 9              run_config                     burke_recompute_audit_strict
# 10             run_config                                        lhs_scope
# 11             run_config                                     lhs_run_type
# 12             run_config                             lhs_sampled_families
# 13  if_family_sensitivity                             aai_agg_p05_masselot
# 14  if_family_sensitivity                             aai_agg_p50_masselot
# 15  if_family_sensitivity                             aai_agg_p95_masselot
# 16  if_family_sensitivity                       aai_agg_n_samples_masselot
# 17  if_family_sensitivity                          aai_agg_source_masselot
# 18  if_family_sensitivity                        aai_agg_p05_masselot_tail
# 19  if_family_sensitivity                        aai_agg_p50_masselot_tail
# 20  if_family_sensitivity                        aai_agg_p95_masselot_tail
# 21  if_family_sensitivity                  aai_agg_n_samples_masselot_tail
# 22  if_family_sensitivity                     aai_agg_source_masselot_tail
# 23  if_family_sensitivity                     aai_agg_p05_burke_polynomial
# 24  if_family_sensitivity                     aai_agg_p50_burke_polynomial
# 25  if_family_sensitivity                     aai_agg_p95_burke_polynomial
# 26  if_family_sensitivity               aai_agg_n_samples_burke_polynomial
# 27  if_family_sensitivity                  aai_agg_source_burke_polynomial
# 28  if_family_sensitivity                       aai_agg_p05_burke_powerlaw
# 29  if_family_sensitivity                       aai_agg_p50_burke_powerlaw
# 30  if_family_sensitivity                       aai_agg_p95_burke_powerlaw
# 31  if_family_sensitivity                 aai_agg_n_samples_burke_powerlaw
# 32  if_family_sensitivity                    aai_agg_source_burke_powerlaw
# 33  if_family_sensitivity  aai_agg_ratio_masselot_tail_to_burke_polynomial
# 34  if_family_sensitivity    aai_agg_ratio_masselot_tail_to_burke_powerlaw
# 35  if_family_sensitivity          aai_agg_ratio_masselot_tail_to_masselot
# 36  if_family_sensitivity       aai_agg_ratio_masselot_to_burke_polynomial
# 37  if_family_sensitivity         aai_agg_ratio_masselot_to_burke_powerlaw
# 38           city_profile                                  population_2020
# 39                 hazard                               citymean_degC_2020
# 40                 hazard                               citymean_degC_2050
# 41                 hazard                    delta_citymean_degC_2050_2020
# 42          vulnerability                                    svi_mean_2020
# 43          vulnerability                                    svi_mean_2050
# 44              mortality                             baseline_deaths_2020
# 45              mortality                             baseline_deaths_2050
# 46                 policy                 avoided_deaths_25y_trees_uniform
# 47                 policy                      avoided_deaths_25y_ac_gross
# 48                 policy                        avoided_deaths_25y_ac_net
# 49                 policy            avoided_deaths_25y_ews_counterfactual
# 50                    cba                   best_cost_effectiveness_policy
# 51                    cba                              best_cost_per_death
# 52            uncertainty                                   aai_agg_median
# 53            uncertainty                                       aai_agg_p5
# 54            uncertainty                                      aai_agg_p95
# 55  if_family_sensitivity                          aai_agg_median_masselot
# 56  if_family_sensitivity                     aai_agg_median_masselot_tail
# 57  if_family_sensitivity     aai_agg_ratio_masselot_loglinear_to_constant
# 58  if_family_sensitivity                            pawn_median_if_family
#
#                          value       unit
# 0                masselot_main        NaN
# 1                masselot_tail        NaN
# 2                     Masselot        NaN
# 3               loglinear_tail        NaN
# 4                  sensitivity        NaN
# 5                         True        NaN
# 6               loglinear_tail        NaN
# 7                         pass        NaN
# 8                            0       rows
# 9                        False        NaN
# 10           masselot_headline        NaN
# 11  masselot_headline_lhs_band        NaN
# 12      masselot_tail,masselot        NaN
# 13                      0.4928  deaths/yr
# 14                      0.7782  deaths/yr
# 15                      1.2114  deaths/yr
# 16                         256    samples
# 17       masselot_headline_lhs        NaN
# 18                      0.5027  deaths/yr
# 19                      0.7507  deaths/yr
# 20                      1.2991  deaths/yr
# 21                         256    samples
# 22       masselot_headline_lhs        NaN
# 23                      0.0681  deaths/yr
# 24                      0.5283  deaths/yr
# 25                      2.3099  deaths/yr
# 26                         512    samples
# 27      burke_conditional_band        NaN
# 28                      0.0519  deaths/yr
# 29                      0.5312  deaths/yr
# 30                      2.4651  deaths/yr
# 31                         512    samples
# 32      burke_conditional_band        NaN
# 33                       1.421      ratio
# 34                       1.413      ratio
# 35                       0.965      ratio
# 36                       1.473      ratio
# 37                       1.465      ratio
# 38                     3424648     people
# 39                       12.56       degC
# 40                       13.06       degC
# 41                        0.51       degC
# 42                       0.477        NaN
# 43                       0.395        NaN
# 44                      1255.6  deaths/yr
# 45                      1708.1  deaths/yr
# 46                        82.8     deaths
# 47                       535.9     deaths
# 48                       167.2     deaths
# 49                      2231.6     deaths
# 50               EWS (central)        NaN
# 51                     11488.0        EUR
# 52                        0.77        NaN
# 53                       0.496        NaN
# 54                       1.247        NaN
# 55                       0.778        NaN
# 56                       0.751        NaN
# 57                        0.96      ratio
# 58                       0.029        NaN
