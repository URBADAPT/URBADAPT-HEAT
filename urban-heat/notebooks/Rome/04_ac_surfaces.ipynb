# %%
from pathlib import Path
import json, pandas as pd, numpy as np

PROJECT = Path(__file__).resolve().parents[2] if '__file__' in globals() else Path.cwd().parents[1]
CFG = PROJECT / "configs" / "rome.yml"
CITY = "Rome"
OUT = PROJECT / "outputs" / CITY
INT = OUT / "interim"
INT.mkdir(parents=True, exist_ok=True)

# optional: tiny loader
import yaml
with open(CFG, "r") as f:
    cfg = yaml.safe_load(f)

print("✔ Loaded config:", CFG)
print("→ Outputs:", OUT)
# Out:
# ✔ Loaded config: /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/configs/rome.yml
# → Outputs: /Users/armandeaboudrar-meda/Desktop/CMCC/URBADAPT/urban-heat/outputs/Rome
